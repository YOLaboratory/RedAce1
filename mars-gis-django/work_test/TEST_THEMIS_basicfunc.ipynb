# %%
from basicfunc import get_spectral
x = get_spectral("I52359002SNU_E_-73.49334_N_30.73279.csv")
# Out:
# Function: Spectral Plot
#
# File name
# I52359002SNU_E_-73.49334_N_30.73279.csv
#
# [[6.78, 0.0007548972644144669, 6.78, 0.0007693268707953393, 7.93, 0.0014614846440963447, 8.56, 0.0016514315211679786, 9.35, 0.001893698936328292, 10.21, 0.002120445715263486, 11.04, 0.0023133214563131332, 11.79, 0.0024888792540878057, 12.57, 0.002476960653439164, 14.88, 0.0005370762301026843]]
# x: wavelength
# [ 6.78  6.78  7.93  8.56  9.35 10.21 11.04 11.79 12.57 14.88]
#
# y: reflectance
# [0.0007549  0.00076933 0.00146148 0.00165143 0.0018937  0.00212045
#  0.00231332 0.00248888 0.00247696 0.00053708]

# %%
print(x[0],x[1])
# Out:
# [ 6.78  6.78  7.93  8.56  9.35 10.21 11.04 11.79 12.57 14.88] [0.0007549  0.00076933 0.00146148 0.00165143 0.0018937  0.00212045
#  0.00231332 0.00248888 0.00247696 0.00053708]

# %%
from basicfunc import standardization
x = standardization("I52359002SNU_E_-73.31904_N_30.72080.csv","I52359002SNU_E_-73.49334_N_30.73279.csv")
# Out:
# Function: Spectral Standardization
#
# File name
# I52359002SNU_E_-73.31904_N_30.72080.csv -Base-
# I52359002SNU_E_-73.49334_N_30.73279.csv -2nd-
#
# y: reflectance -base-
# [0.00093913 0.00101472 0.00186478 0.00210023 0.0022821  0.00255863
#  0.00274634 0.00291043 0.00286097 0.00053431]
# y: reflectance -2nd-
# [0.0007549  0.00076933 0.00146148 0.00165143 0.0018937  0.00212045
#  0.00231332 0.00248888 0.00247696 0.00053708]
#
# x: wavelength
# [ 6.78  6.78  7.93  8.56  9.35 10.21 11.04 11.79 12.57 14.88]
#
# y: reflectance -standardization_2nd/base-
# [0.80382513 0.75816446 0.78373012 0.78630993 0.82980366 0.82874155
#  0.8423289  0.85515932 0.86577714 1.00517778]

# %%
from basicfunc import moving_avg
x = moving_avg("I52359002SNU_E_-73.31904_N_30.72080.csv", 4)
# Out:
# Function: Spectral Moving Average
#
# File name
# I52359002SNU_E_-73.31904_N_30.72080.csv
#
# x: wavelength
# [ 6.78  6.78  7.93  8.56  9.35 10.21 11.04 11.79 12.57 14.88]
#
# y: reflectance
# [0.00093913 0.00101472 0.00186478 0.00210023 0.0022821  0.00255863
#  0.00274634 0.00291043 0.00286097 0.00053431]
#
# y: reflectance  -Moving Average-
# [       nan        nan 0.00147972 0.00181546 0.00220144 0.00242183
#  0.00262438 0.00276909 0.00226301        nan]

# %%
from basicfunc import spectralplot
spectralplot(x)
# Out:
# No.1
# [ 6.78  6.78  7.93  8.56  9.35 10.21 11.04 11.79 12.57 14.88]
# [0.00093913 0.00101472 0.00186478 0.00210023 0.0022821  0.00255863
#  0.00274634 0.00291043 0.00286097 0.00053431]
# No.2
# [ 6.78  6.78  7.93  8.56  9.35 10.21 11.04 11.79 12.57 14.88]
# [       nan        nan 0.00127288 0.00165991 0.00208237 0.00231366
#  0.00252903 0.00273847 0.00283925 0.0021019 ]
